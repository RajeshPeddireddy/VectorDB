# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeshPeddireddy/VectorDB/blob/main/AdvancedRAGTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Report Name	Assumed Performance Advances
# Report Description:	The purpose of this report is to show assumed performance advances for all sellers that have been paid along with the recoveries that have occurred.
#
# Report Name	Attainment % Outlier Analysis Report
# Report Description:	This report will show trending of Attainment % YOY as well as Attainment % against universes (Business Unit, Segment, Sales Center, Abstract) in order to find any payment anomalies. This will include Z-scores that are graded against their specific universe.
#
#
# Report Name	Commission Adjustment Report
# Report Description:	Details of all adjustments to commissions throughout the year by seller
#
#
# Report Name	Commission Exceeding Plan Year Cap
# Report Description:	Shows all sellers whose commissions exceeds the Plan Year Cap, this report is used by finance to analyze the people who are hitting their cap
#
# Report Name	Commission Limiter Report
# Report Description:	Displays a breakdown of commission limiter sets for sellers who have a Production component. This is the max amount of commissions they may receive for the shown period.
#
# Report Name	Commissions Hold Report
# Report Description:	Any Commissions that were earned but not paid will appear on this report. This will include manually held commissions or comissions held by a lack of DOU.
#
# Report Name	Comp Analysis (View)
# Report Description:	This report helps the Finance Team with their analysis of pay. It is ingested into systems for their analysis.
#
# Report Name	Comp Status Event Overrides (View)
# Report Description:	The report displays any instances where a Comp Status has been manually deleted year-to-date. Data can come in incorrect from feeds and this is where the information would show that they corrected it.
#
# Report Name	Deficit Report (View)
# Report Description:	This report shows all deficits for analysis as well as off comp-deficits to transfer to payroll for payment recovery.
#
# Report Name	Earnings Outlier Analysis Report
# Report Description:	This report will show trending of Earnings YOY as well as Earnings against universes (Business Unit, Segment, Sales Center, Abstract) in order to find any payment anomalies. This will include their z-score against their universes.
#
# Report Name	Employee Closeout Report
# Report Description:	To provide visibility into what employee closeouts need to be checked for in Varicent
#
# Report Name	Flat Payment Report
# Report Description:	Provide visibility into which sellers have flat payments during which months. If the flat payments are able to be tied to a measure, they will show here, otherwise there will be no measure information.
#
# Report Name	Headcount Analysis Detail (View)
# Report Description:	"This report provides a total headcount by title and by month at a Nation (or Global) level.
# This report is used by Plan design to do analysis and determine how many employees will be impacted by any changes they will make in the system."
#
# Report Name	Level Based Metrics Payment Report (View)
# Report Description:	This report displays the Category, Metrics Rating and Payment details by employee. This helps provide an analysis point for the Comp Admin team to see which plans are being paid in what way.
#
# Report Name	Metrics and Milestones Rating Report
# Report Description:	This report displays the Category and Metrics Rating details by Abstract and Sales Center so the teams can analyze if a metric is being measured correctly.
#
# Report Name	MOM Trending Report (Annual) (view)
# Report Description:	This report will show trending of pay MOM for components with annual quotas in order to find any payment anomalies.
#
# Report Name	MOM Trending Report (Monthly) (view)
# Report Description:	This report will show trending of pay MOM for measures with a monthly quota in order to find any payment anomalies. This will also include the attainment of the different universes the employee is in (Business unit, Segment, Sales center) as a whole and their difference from the universe.
#
# Report Name	No Signed DOU Report
# Report Description:	To show a list of all sellers who haven't signed a DOU and their information for analysis
#
# Report Name	Other Production Detail Report
# Report Description:	This report will show details of any production results that are not included in our other transaction reports. We'll need to make this accessible to sellers to see information on their metrics and what the results look like.
#
# Report Name	Other Production Summary
# Report	Report Description:	This report will show a summary of any production results that are not included in other transactional reports.
#
# Report Name	Parental Leave Report
# Report Description:	To show how parental leave affects quota for measures within respective earn buckets for all sellers who are marked as on Parental Leave. This report will only show measures that are eligible for PPL.
#
# Report Name	Pay Tape Report
# Report Description:	Show EOW Check and Special Check payment amount for the month
#
# Report Name	Payment Review Report
# Report Description:	"Showcase any larger than ordinary payments that need to be reviewed
# Showcase any large incentive payments that need reviewing"
#
# Report Name	Payroll Deficit Report
# Report Description:	To see all adjustments made to the DTTP code, includes US sellers clearing their balance at EOY, clearing negative balances, terminations, transfer out of sales activity.
#
# Report Name	Payroll Security (View)
# Report Description:	This view will provide insight into anyone who is an role other than seller who is currently receiving pay from commissions.
#
# Report Name	Production Attainment Detail Report
# Report Description:	To show where the production results and adjustments are coming from at a seller level for analysis
#
# Report Name	Production Results View	Report Description:	This report will show a breakdown of all results received for production measure by sellers. It should include any adjustments that have been made to measure manually as well. It will help analyze where results are coming from.
#
# Report Name	Production Sales YTD
# Report Description:	This report will be used to research production sales at a SIP level. It includes 1 line per SIP and all sellers are concatenated and separated by their title groups.
#
# Report Name	Production Sales YTD - Reviewer	Report Description:	This report will be used to research production sales at a SIP level. It will include 1 row per SIP so that the information can be researched by sale. It will also include reviewing information for the Comp Admin team to review. This report will show YTD SIP information for the EOW Months listed.
#
# Report Name	Production Sales YTD by Employee
# Report Description:	This report will be used to research production sales at a SIP level. It will include 1 row per SIP per employee so that the information can be researched by seller.
#
# Report Name	Production Sales YTD by Employee - Reviewer
# Report Description:	This report will be used to research production sales at a SIP level. It will include 1 row per SIP per employee so that the information can be researched by seller. It will also include reviewing information for the Comp Admin team to review.
#
# Report Name	Quota Tool TBR Import Error Report (View)
# Report Description:	This report displays records not processed from the QuotaToolTBR feed due to incorrect data received from the feed or Eligibility errors
#
# Report Name	Quota Tool TBR Imported Records (View)
# Report Description:	The report displays all records successfully processed from the QuotaToolTBR feed.
#
# Report Name	Sales Center
# Report Bucket Total SIP Results (View)	Report Description:	This report includes monthly SIP results totals along with a YTD sum by Report Bucket and Sales Center. It will help perform analysis on SIP results.
#
# Report Name	Sales Centers (View)
# Report Description:	Displays the associated Segment, Admin Group and Sales Center Name for the plan year. This will assist Comp Admin with 3
# knowing what codes to load for the Sales Center Assignment table.
#
# Report Name	Sales For Same Customer In Multiple Sales Centers (View)
# Report Description:	This report will show all SIP sales for customers that are in multiple sales centers.
#
# Report Name	Sales Metrics and Customer Experience Employee View
# Report Description:	This report displays the Category, Metrics Rating and Payment details by employee so that you can find any employees missing a rating or what a specific employee was rated at a specific time for a specific period.
#
#
# Report Name	SC Rollup (Service Eligibility)
# Report Description:	This report would show the presorted set of results by Sales Center and Report Bucket available for drilldown
#
# Report Name	SC Rollup (Assignment)
# Report Description:	This report would show the presorted set of results by Sales Center and Report Bucket available for drilldown
#
# Report Name	SIP Eligibility Errors
# Report Description:	This report will show SIP crediting errors for all participants including Service Error (seller's abstract was not eligible for the service), Comp % Error (seller had 0% On Comp), Split % Error (Split % of all sellers on 1 Title Group exceeded 100% Split Percent)
#
# Report Name	SIP High Production Attainment and Large Incentive Payment (View)
# Report Description:	This report will help Comp Admin run audits on any large incentive payments or high production attainment SIPs for employees. They will need to filter this down for the information they want to see with regards to high attainment and large incentive payments.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
